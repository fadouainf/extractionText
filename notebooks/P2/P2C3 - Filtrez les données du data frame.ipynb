# %% [markdown]
# ![openclassrooms](https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/6204541/1+HnqdJ-5ofxiPP9HIxdNdpw.jpeg)
#
# # Filtrez les données du dataframe
#
# Nous allons à présent aller un peu plus loin dans la manipulation de nos prêts bancaires. Les demandes suivantes ont été formulées par le responsable du service prêt de notre établissement :
# - Le taux d’endettement autorisé est de 35%. Pourriez vous me communiquer le nombre de personnes ayant dépassé ce seuil ?
# - Même question, mais cette fois ci uniquement sur l’agence Parisienne
# - Pour faciliter le traitement d’éventuelles futures demandes de prêts, pourriez vous ajouter une variable nommée `risque` qui nous permettrait d’identifier les clients risqués facilement
# - Combien de prêts automobiles ont été accordés ? Quel est le coût total moyen de ces derniers ?
# - Quel est le bénéfice mensuel total réalisé par l’agence Toulousaine ?
#
# Vous allez devoir mettre en application l’ensemble des processus de sélection présentés ci-dessus pour répondre à ces différentes demandes.

# %%
import numpy as np
import pandas as pd

# %%
# traitement réalisés précédemment
prets = pd.read_csv('https://raw.githubusercontent.com/OpenClassrooms-Student-Center/fr-4452741-decouvrez-les-librairies-python-pour-la-data-science/main/data/prets.csv')

# calcul du taux d'endettement
prets['taux_endettement'] = round(prets['remboursement'] * 100 / prets['revenu'], 2)

# renommer taux en taux_interet
prets.rename(columns={'taux':'taux_interet'}, inplace=True)

# calculer le cout total du pret
prets['cout_total'] = prets['remboursement'] * prets['duree']

# calculer les bénéfices mensuels réalisés
prets['benefices'] = round((prets['cout_total'] * prets['taux_interet']/100)/(24), 2)

prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices
# 0         1.168             30.80    271212.0     131.99
# 1         3.701              4.52     15360.0      23.69
# 2         1.173             23.50    374355.0     182.97
# 3         0.972             29.50    132609.6      53.71
# 4         1.014             34.80    105485.4      44.57

# %% [markdown]
# Le taux d’endettement autorisé est de 35%. Pourriez vous me communiquer le nombre de personnes ayant dépassé ce seuil ? vous pourrez me stocker la liste dans une variable à part nommé `clients_risque`

# %%
clients_risque=prets.loc[prets['taux_endettement']>35,:]
display(clients_risque.head())
nb=clients_risque.shape[0]
print("le nombre des clients qui ont un taux d'endettement depassé de 35% sont:",nb)
# Out:
#     identifiant      ville     CP  revenu  remboursement  duree        type  \
# 7             6       LYON  69008  1867.0         711.33    240  immobilier
# 8             7       NICE   6000  5486.0        2956.95    300  immobilier
# 10            9  MARSEILLE  13012  1386.0         612.61    180  immobilier
# 15           14   TOULOUSE  31400  2413.0        1334.39    300  immobilier
# 21           20       LYON  69001  3318.0        1237.61    240  immobilier
#
#     taux_interet  taux_endettement  cout_total  benefices
# 7          1.196              38.1    170719.2      85.08
# 8          1.184              53.9    887085.0     437.63
# 10         1.284              44.2    110269.8      58.99
# 15         1.154              55.3    400317.0     192.49
# 21         1.148              37.3    297026.4     142.08
# le nombre des clients qui ont un taux d'endettement depassé de 35% sont: 58

# %% [markdown]
# Même question, mais cette fois ci uniquement sur l’agence Parisienne

# %%
clients_risque=prets.loc[(prets['taux_endettement']>35)&(prets['ville']=='PARIS'),:]
display(clients_risque.head(20))
nb=clients_risque.shape[0]
print("le nombre des clients qui ont un taux d'endettement depassé de 35% sont:",nb)
# Out:
#      identifiant  ville     CP  revenu  remboursement  duree        type  \
# 70            67  PARIS  75014  5598.0        2395.94    240  immobilier
# 75            72  PARIS  75012  5981.0        2230.91    240  immobilier
# 89            85  PARIS  75005  6341.0        2980.27    240  immobilier
# 129          122  PARIS  75001  6536.0        2457.54    120  immobilier
# 143          134  PARIS  75003  2870.0        1021.72    180  immobilier
# 155          145  PARIS  75017  5978.0        2193.93    300  immobilier
# 181          168  PARIS  75003  6366.0        2807.41    240  immobilier
# 183          170  PARIS  75019  2384.0        1311.20    240  immobilier
# 186          173  PARIS  75006  6784.0        3744.77    180  immobilier
# 195          182  PARIS  75019  4068.0        1505.16    240  immobilier
# 196          183  PARIS  75001  2330.0         871.42    240  immobilier
# 203          190  PARIS  75005  2576.0         984.03    240  immobilier
# 224          210  PARIS  75016  5846.0        3104.23    180  immobilier
# 227          212  PARIS  75008  4749.0        1766.63    300  immobilier
# 232          217  PARIS  75001  2064.0         825.60    180  immobilier
# 242          226  PARIS  75002  5098.0        2910.96    240  immobilier
#
#      taux_interet  taux_endettement  cout_total  benefices
# 70          1.136              42.8    575025.6     272.18
# 75          1.150              37.3    535418.4     256.55
# 89          1.074              47.0    715264.8     320.08
# 129         1.038              37.6    294904.8     127.55
# 143         1.104              35.6    183909.6      84.60
# 155         1.081              36.7    658179.0     296.45
# 181         1.176              44.1    673778.4     330.15
# 183         1.051              55.0    314688.0     137.81
# 186         1.248              55.2    674058.6     350.51
# 195         1.080              37.0    361238.4     162.56
# 196         1.137              37.4    209140.8      99.08
# 203         1.029              38.2    236167.2     101.26
# 224         1.141              53.1    558761.4     265.64
# 227         1.077              37.2    529989.0     237.83
# 232         1.067              40.0    148608.0      66.07
# 242         1.140              57.1    698630.4     331.85
# le nombre des clients qui ont un taux d'endettement depassé de 35% sont: 16

# %% [markdown]
# Pour faciliter le traitement d’éventuelles futures demandes de prêts, pourriez vous ajouter une variable nommée `risque` qui aurait pour valeur `Oui` si le client est risqué (taux d’endettement > 35%), `Non` sinon.
# Pour se faire, je vous conseille de créer la variable `risque` en l'initialisant à `Non` (ou `Oui`, à votre préférence) et de ne modifier que les lignes concernées par la valeur inverse :

# %%
prets['risque']='Non'
prets.loc[prets['taux_endettement']>35,'risque']='Oui'
display(prets.head(10))
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
# 5            4  MARSEILLE  13012  1476.0         423.61    240  immobilier
# 6            5      PARIS  75016  2476.0         836.89    240  immobilier
# 7            6       LYON  69008  1867.0         711.33    240  immobilier
# 8            7       NICE   6000  5486.0        2956.95    300  immobilier
# 9            8   BORDEAUX  33200  3578.0         751.38    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices risque
# 0         1.168             30.80    271212.0     131.99    Non
# 1         3.701              4.52     15360.0      23.69    Non
# 2         1.173             23.50    374355.0     182.97    Non
# 3         0.972             29.50    132609.6      53.71    Non
# 4         1.014             34.80    105485.4      44.57    Non
# 5         1.209             28.70    101666.4      51.21    Non
# 6         1.116             33.80    200853.6      93.40    Non
# 7         1.196             38.10    170719.2      85.08    Oui
# 8         1.184             53.90    887085.0     437.63    Oui
# 9         1.316             21.00    135248.4      74.16    Non

# %% [markdown]
# Combien de prêts automobiles ont été accordés ? Quel est le coût total moyen de ces derniers ?

# %%
pret_automobile=prets.loc[(prets['type']=='automobile'),:]
print('le nombre de prets automobile accordé est:',pret_automobile.shape[0])
display(pret_automobile)
cout_tot=pret_automobile['cout_total'].mean()
print("le cout myen est:",cout_tot)
# Out:
# le nombre de prets automobile accordé est: 16
#      identifiant      ville     CP  revenu  remboursement  duree        type  \
# 1              1      PARIS  75009  5310.0          240.0     64  automobile
# 65            63       NICE   6300  4114.0          302.9     24  automobile
# 67            64       LYON  69004  4326.0          236.1     46  automobile
# 87            83   TOULOUSE  31000  2207.0          253.3     60  automobile
# 100           95      PARIS  75016  6069.0          341.4     24  automobile
# 106          101       LYON  69008  4737.0          214.8     47  automobile
# 120          113  MARSEILLE  13006  2314.0          253.2     49  automobile
# 132          124       NICE   6000  3493.0          309.9     56  automobile
# 141          133      PARIS  75011  3099.0          291.2     78  automobile
# 154          144  MARSEILLE  13010  2240.0          316.6     81  automobile
# 158          147  MARSEILLE  13015  1288.0          269.8     30  automobile
# 159          148   TOULOUSE  31000  1872.0          250.5     80  automobile
# 172          159      PARIS  75010  3238.0          315.8     55  automobile
# 209          195       LYON  69006  2468.0          337.9     38  automobile
# 225          211   TOULOUSE  31400  3724.0          215.0     43  automobile
# 240          224      PARIS  75008  5118.0          238.2     25  automobile
#
#      taux_interet  taux_endettement  cout_total  benefices risque
# 1           3.701              4.52     15360.0      23.69    Non
# 65          3.092              7.36      7269.6       9.37    Non
# 67          3.124              5.46     10860.6      14.14    Non
# 87          2.975             11.48     15198.0      18.84    Non
# 100         3.644              5.63      8193.6      12.44    Non
# 106         3.487              4.53     10095.6      14.67    Non
# 120         2.954             10.94     12406.8      15.27    Non
# 132         3.012              8.87     17354.4      21.78    Non
# 141         3.508              9.40     22713.6      33.20    Non
# 154         3.267             14.13     25644.6      34.91    Non
# 158         3.314             20.95      8094.0      11.18    Non
# 159         3.519             13.38     20040.0      29.38    Non
# 172         2.995              9.75     17369.0      21.68    Non
# 209         3.472             13.69     12840.2      18.58    Non
# 225         3.374              5.77      9245.0      13.00    Non
# 240         3.423              4.65      5955.0       8.49    Non
# le cout myen est: 13665.0

# %% [markdown]
# Quel est le bénéfice mensuel total réalisé par l’agence Toulousaine ?

# %%
pret_benefice=prets.loc[(prets['ville']=='TOULOUSE'),:]
print('le nombre de benefice de taulouse:',pret_benefice.shape[0])
display(pret_benefice.head(5))
benefice_tot=pret_benefice['benefices'].sum()
print(f"le bénéfice mensuel total réalisé par l’agence Toulousaine  est:{benefice_tot:.2f}")

prets.loc[prets['ville'] == 'TOULOUSE', 'benefices'].sum()
# Out:
# le nombre de benefice de taulouse: 27
#     identifiant     ville     CP  revenu  remboursement  duree        type  \
# 0             0  TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 15           14  TOULOUSE  31400  2413.0        1334.39    300  immobilier
# 31           30  TOULOUSE  31000  1785.0         514.08    240  immobilier
# 41           40  TOULOUSE  31400  3837.0         621.59    240  immobilier
# 50           49  TOULOUSE  31100  2931.0        1442.05    240  immobilier
#
#     taux_interet  taux_endettement  cout_total  benefices risque
# 0          1.168              30.8    271212.0     131.99    Non
# 15         1.154              55.3    400317.0     192.49    Oui
# 31         1.041              28.8    123379.2      53.52    Non
# 41         1.205              16.2    149181.6      74.90    Non
# 50         1.200              49.2    346092.0     173.05    Oui
# le bénéfice mensuel total réalisé par l’agence Toulousaine  est:2138.07
# 2138.0699999999997

# %% [markdown]
# Félicitation ! Je vous invite fortement à vérifier vos réponses avec [la correction ci contre](https://colab.research.google.com/github/OpenClassrooms-Student-Center/fr-4452741-decouvrez-les-librairies-python-pour-la-data-science/blob/main/notebooks/P2/P2C3%20-%20Filtrez%20les%20donn%C3%A9es%20du%20data%20frame%20-%20correction.ipynb).
